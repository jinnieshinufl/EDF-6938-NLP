# %% [markdown]
# #### Final Proposal EDF 6938: Natural Langauge Processing
#
# ### Exploring the  relationships of expressed emotions from student and faculty - re-sponses from  Hidden Curriculum Awareness Survey
# > #### Author: Edwin Marte
# > #### Date: Dic 04 2022
# > #### Email: emartezorrilla@ufl.edu

# %% [markdown]
# #### 1. Introduction
#
# >
# In school settings, the curriculum can be classified in-to three basic types: formal curriculum; null curriculum; and hidden curriculum [5]. A formal curriculum is guided by a study plan, it is the traditional educational setup. The null curriculum is the one that is not taught because of ad-ministrative directives or instructor decisions for any reason. In an academic setting, the term "hidden curriculum" (HC) refers to the unstated, unofficial, and frequently unex-pected lessons, beliefs, and viewpoints that are expressed physically [1].
#
# Previous works including hidden curriculum have been performed in areas such as medicine, psychology, education, and sociology moistly to predict consequences when HC is left unattended. Little effort has been done looking to the positive side of HC such as improving stu-dent performance, exam scores, or retention rate. HC awareness could potentially impact some decisions in edu-cation to improve areas such as engineering identity, stu-dent performance, and much more [1].

# %% [markdown]
# #### 2. Related Work
#
# >
# As mentioned before previous work has been con-ducted in HC studying the consequences of not attending it conversely in engineering education this trend has been scarce. Only [1] and [4-8] have developed a mixed-method study that has produced several results. Their original study has over 200 participants. The participants were engineer-ing students and faculty from across the United States (US) and Puerto Rico (PR) [9].
#
# For example in [1], ten different questions were of-fered as a vignette survey to the participants. The questions covered Raw engineering perception, Hidden Curriculum Awareness, emotions, self-efficacy, self-advocacy, wrap-up questions, and demographics. All questions gathered qualitative data and four returned also quantitative data. Also in [1] only a quantitative analysis was performed. The study found reliability scores exceeding 0.70 suggesting an adequately reliable scale for the intended engineering population.
#
# Another related study applied a survey during the 2017 SHPE convention [5]. The primary question was: What primary HC perspectives did Latinx faculty use to describe their experiences with engineering education throughout the professional development sessions activities and surveys? The authors proceeded with manual coding and found the following themes: (a) professional expecta-tions in engineering; (b) types of stresses in meeting profes-sional expectations in engineering and (c) views of stress for their engineering students [5].
#
# All works related to HC and engineering education have so far relied on survey application and then either partial quantitative or partial qualitative analysis. Although results look promising and open doors to increase research in this field none were found to be applying any automatic analysis or application of machine learning algorithm. [1] reported emotional questions in their survey but did not provide results or analysis. With the surveys, questions, and responses provided by [1] and [4-8] other types of analysis including sentiment analysis could enrich the HC research field.

# %% [markdown]
# #### 3. Methods
#
# **3.1	Methodologically related work**
#
# This work will use the dataset gathered from [1] con-sisting of ten types of questions ranging from raw engineer-ing belief to demographic data. Only the responses from HC awareness demographics and emotions will be used for this project. 967 responses from engineering students and faculties from across the US and Puerto Rico are provided.
#
# **3.2	Purpose of the Study and RQs**
# The purpose of this study is to explore the relationship between Qualitative and Quantitative emotions responses due to Hidden Curriculum from a Vignette Survey Instru-ment among Engineering Students and Faculty. Sentiment Analysis and NLP will be used to find the relationship be-tween the variables and the Demographics.
#
# **Research Question:**
# The Research Question for this project is: What are the sentiments and emotions expressed by engineering students and faculty regarding Hidden curriculum aware-ness.
#
# The hypothesis for this work is: Faculties Will have more positive sentiments and emotions expressed to Hid-den curriculum awareness than engineering students. Work in [4] returned similar results for a difficulty index during an exam. The instructor always underestimates the diffi-culty of the question more than the student conversely for HC curriculum is expected to be similar.
#
# **3.3 	Data or Data collection**
#
# The Data used in this study comes from [1] which us-es introduces the development and assessment of the quantitative portion of a mixed-methods vignette survey instrument designed to explore students’ and faculties’ responses to hidden curriculum. The data from this study represent more than 900 responses from engineering stu-dents and faculty from across the United States (US) and Puerto Rico (PR).
#
# **3.4	Analysis Framework or Plan**
# The proposed framework for this project consists of three steps as outlined in figure 1. The first step is the pre-processing, the second is the training, and the third is the classification. Preprocessing has a six-part sub-stage pro-cess while the training and classification will use a two-model configuration.
#
# ![Picture1.png](data:image/png;base64,...)
#
# Figure 1.
#
# **Preprocessing Steps:**
# *	Removing punctuations: using the Python string module
# *	Removing Stop words: using NLTK (Natural Lan-guage Toolkit)
# *	Lower casing: Converting a word to lowercase
# *	Tokenization: using NLTK (Natural Language Toolkit) to Splitting the sentence into words.
# *	Stemming: It is a process of transforming a word to its root form also using NLTK (Natural Lan-guage Toolkit)
# *	Lemmatization: reduces the words to a word ex-isting in the language, using NLTK (Natural Lan-guage Toolkit)
#
# **Training and Classification:**
#
# For Training two models are going to be used: Va-lence Aware Dictionary for sentiment Reasoning (Vader) for sentiment Analysis and a pre-trained emotion analysis tool [2]. Vader will provide a compound score that will range between negative and positive numbers to classify the sentiment from the response as positive, negative, or neutral. For the emotion analysis tool, [3] used 73 billion tweets to train a recurrent neural network proving six types of emotion for classification (Joy, Fear, Sadness, Anger, surprise, and disgust). Results from this classifier provide a performance that ranges between 54% and 83% for each emotion.

# %% [markdown]
# #### 4. Analysis Demonstration

# %% [markdown]
# ##### 4.1. Dependencies

# %%
# Import all the library that is necessary for your analysis 
#!pip install { } ! in case you run into the `package not avaialble` error
import pandas as pd 
import numpy as np 

import os

# !pip install syllables #run this if you run into an error (download syllables)
#import syllables 

import nltk
#nltk.download('punkt')
nltk.download('stopwords')
from nltk.stem import *

nltk.download(['punkt', 'wordnet', 'omw-1.4'])
# !pip install unicode

import re

from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
# !pip install autocorrect
from autocorrect import Speller
#from autocorrect import Speller
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from nltk import word_tokenize
import string
import timeit

import matplotlib.pyplot as plt

from time import time
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.model_selection import train_test_split


# !pip install teanos

# !pip install tensorflow

# !pip install keras
#############################################################
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ##### 4.2. Code

# %%
#### Your code for the analysis will be provided here 
## This code was run locally - not to be run in this file
## it was posted here for demonstration only

''' Open Files'''
pathf= "C:/Users/marte/OneDrive - University of Florida/EED_PHD_EM_shared_2020/Papers_WorkinPorgress/13 NLP Analysis hidden Curriculum/code"
df1 = pd.read_csv(pathf+'/Data 1 V1.0.csv')
df1.drop(df1.iloc[:, 34:38], inplace=True, axis=1)
df1.drop(df1.iloc[:, 0:2], inplace=True, axis=1)

df2 = pd.read_csv(pathf+'/Data 2 V1.0.csv')
df2=df2.drop(df2.loc[:, 'Q.4.2':'Q.8.2'].columns, axis=1)
df2=df2.drop(df2.loc[:, 'Q3.1.#1_3':'Q7.1.#1_6'].columns, axis=1)


#create dtafile new file and header
names=df1.columns.append(df2.columns)
full_data = pd.DataFrame(columns=names)

#get colum 4.2 to compare
ds1=df1.loc[:,["Q.4.2"]]

j=0   #conunt for ds1
for i in range(len(ds1)):
#for i in range(1):
    while j < len(df2):    
    #while j < 2:    
        if df1["ID"][i]==df2["ID"][j]:
            df3=df2[j:j+1].copy()
            df4=df1[i:i+1].copy()            
            full_data = full_data.append(pd.concat([df4.reset_index(drop=True),df3.reset_index(drop=True)], axis=1), ignore_index = True)
            j=j+1
           
            break
        else: 
            j=j+1
       
file_selected=os.path.join(os.path.join(pathf)+"/") 
full_data.to_csv(file_selected+"full_data.csv")
####################################################

# %%
#Preparing / Importing for Vaader
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
#vader testing vader
### Preprocessing Data, Results in Data1

#Most of the code gather form here
#### Source https://towardsdatascience.com/cleaning-preprocessing-text-data-by-building-nlp-pipeline-853148add68a

#prepare Data
filename = 'full_data.csv'
data = pd.read_csv(filename)
data=data.rename(columns={"Q.4.2": "responses","Q1.1.": "roles","Q1.3.": "field","Q1.6.": "gender","Q1.8._11": "ethnicity","Q1.9.": "First Generation","Q1.10.": "Non Tradional"})
data=data[["responses","roles","field","gender","ethnicity","First Generation","Non Tradional"]]
responses=data['responses']


def remove_newlines_tabs(text):
    """
    This function will remove all the occurrences of newlines, tabs, and combinations like: \\n, \\.
    
    arguments:
        input_text: "text" of type "String". 
                    
    return:
        value: "text" after removal of newlines, tabs, \\n, \\ characters.
        
    Example:
    Input : This is her \\ first day at this place.\n Please,\t Be nice to her.\\n
    Output : This is her first day at this place. Please, Be nice to her. 
    
    """
    
    # Replacing all the occurrences of \n,\\n,\t,\\ with a space.
    Formatted_text = text.replace('\\n', ' ').replace('\n', ' ').replace('\t',' ').replace('\\', ' ').replace('. com', '.com')
    return Formatted_text
# len of data :- 1618647 lac words


def strip_html_tags(text):
    """ 
    This function will remove all the occurrences of html tags from the text.
    
    arguments:
        input_text: "text" of type "String". 
                    
    return:
        value: "text" after removal of html tags.
        
    Example:
    Input : This is a nice place to live. 
    Output : This is a nice place to live.  
    """
    # Initiating BeautifulSoup object soup.
    soup = BeautifulSoup(text, "html.parser")
    # Get all the text other than html tags.
    stripped_text = soup.get_text(separator=" ")
    return stripped_text
# len of string:- 1616053 lac words


def remove_links(text):
    """
    This function will remove all the occurrences of links.
    
    arguments:
        input_text: "text" of type "String". 
                    
    return:
        value: "text" after removal of all types of links.
        
    Example:
    Input : To know more about cats and food & website: catster.com  visit: https://catster.com//how-to-feed-cats
    Output : To know more about cats and food & website: visit:     
    
    """
    
    # Removing all the occurrences of links that starts with https
    remove_https = re.sub(r'http\S+', '', text)
    # Remove all the occurrences of text that ends with .com
    remove_com = re.sub(r"\ [A-Za-z]*\.com", " ", remove_https)
    return remove_com
# len of words:- 1616053

def remove_whitespace(text):
    """ This function will remove 
        extra whitespaces from the text
    arguments:
        input_text: "text" of type "String". 
                    
    return:
        value: "text" after extra whitespaces removed .
        
    Example:
    Input : How   are   you   doing   ?
    Output : How are you doing ?     
        
    """
    pattern = re.compile(r'\s+') 
    Without_whitespace = re.sub(pattern, ' ', text)
    # There are some instances where there is no space after '?' & ')', 
    # So I am replacing these with one space so that It will not consider two words as one token.
    text = Without_whitespace.replace('?', ' ? ').replace(')', ') ')
    return text    
# len of words:- 1596248 lac words


import unicodedata
def strip_accents(s):
   return ''.join(c for c in unicodedata.normalize('NFD', s)
                  if unicodedata.category(c) != 'Mn')
   
# Code for accented characters removal
def accented_characters_removal(text):
    # this is a docstring
    """
    The function will remove accented characters from the 
    text contained within the Dataset.
       
    arguments:
        input_text: "text" of type "String". 
                    
    return:
        value: "text" with removed accented characters.
        
    Example:
    Input : Málaga, àéêöhello
    Output : Malaga, aeeohello    
        
    """
    # Remove accented characters from text using unidecode.
    # Unidecode() - It takes unicode data & tries to represent it to ASCII characters. 
    text = unidecode.unidecode(text)
    return text
# Len of data:- 1593952 lac of words


# Code for text lowercasing
def lower_casing_text(text):
    
    """
    The function will convert text into lower case.
    
    arguments:
         input_text: "text" of type "String".
         
    return:
         value: text in lowercase
         
    Example:
    Input : The World is Full of Surprises!
    Output : the world is full of surprises!
    
    """
    # Convert text to lower case
    # lower() - It converts all upperase letter of given string to lowercase.
    text = text.lower()
    return text


# Code for removing repeated characters and punctuations

def reducing_incorrect_character_repeatation(text):
    """
    This Function will reduce repeatition to two characters 
    for alphabets and to one character for punctuations.
    
    arguments:
         input_text: "text" of type "String".
         
    return:
        value: Finally formatted text with alphabets repeating to 
        two characters & punctuations limited to one repeatition 
        
    Example:
    Input : Realllllllllyyyyy,        Greeeeaaaatttt   !!!!?....;;;;:)
    Output : Reallyy, Greeaatt !?.;:)
    
    """
    # Pattern matching for all case alphabets
    Pattern_alpha = re.compile(r"([A-Za-z])\1{1,}", re.DOTALL)
    
    # Limiting all the  repeatation to two characters.
    Formatted_text = Pattern_alpha.sub(r"\1\1", text) 
    
    # Pattern matching for all the punctuations that can occur
    Pattern_Punct = re.compile(r'([.,/#!$%^&*?;:{}=_`~()+-])\1{1,}')
    
    # Limiting punctuations in previously formatted string to only one.
    Combined_Formatted = Pattern_Punct.sub(r'\0', Formatted_text)
    
    # The below statement is replacing repeatation of spaces that occur more than two times with that of one occurrence.
    Final_Formatted = re.sub(' {2,}',' ', Combined_Formatted)
    return Final_Formatted


CONTRACTION_MAP = {
"ain't": "is not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have",
}
# The code for expanding contraction words
def expand_contractions(text, contraction_mapping =  CONTRACTION_MAP):
    """expand shortened words to the actual form.
       e.g. don't to do not
    
       arguments:
            input_text: "text" of type "String".
         
       return:
            value: Text with expanded form of shorthened words.
        
       Example: 
       Input : ain't, aren't, can't, cause, can't've
       Output :  is not, are not, cannot, because, cannot have 
    
     """
    # Tokenizing text into tokens.
    list_Of_tokens = text.split(' ')

    # Checking for whether the given token matches with the Key & replacing word with key's value.
    
    # Check whether Word is in lidt_Of_tokens or not.
    for Word in list_Of_tokens: 
        # Check whether found word is in dictionary "Contraction Map" or not as a key. 
         if Word in CONTRACTION_MAP: 
                # If Word is present in both dictionary & list_Of_tokens, replace that word with the key value.
                list_Of_tokens = [item.replace(Word, CONTRACTION_MAP[Word]) for item in list_Of_tokens]
                
    # Converting list of tokens to String.
    String_Of_tokens = ' '.join(str(e) for e in list_Of_tokens) 
    return String_Of_tokens     


    
# The code for removing special characters
def removing_special_characters(text):
    """Removing all the special characters except the one that is passed within 
       the regex to match, as they have imp meaning in the text provided.
   
    
    arguments:
         input_text: "text" of type "String".
         
    return:
        value: Text with removed special characters that don't require.
        
    Example: 
    Input : Hello, K-a-j-a-l. Thi*s is $100.05 : the payment that you will recieve! (Is this okay?) 
    Output :  Hello, Kajal. This is $100.05 : the payment that you will recieve! Is this okay?
    
   """
    # The formatted text after removing not necessary punctuations.
    Formatted_Text = re.sub(r"[^a-zA-Z0-9:$-,%.?!]+", ' ', text) 
    # In the above regex expression,I am providing necessary set of punctuations that are frequent in this particular dataset.
    return Formatted_Text

# The code for spelling corrections
def spelling_correction(text):
    ''' 
    This function will correct spellings.
    
    arguments:
         input_text: "text" of type "String".
         
    return:
        value: Text after corrected spellings.
        
    Example: 
    Input : This is Oberois from Dlhi who came heree to studdy.
    Output : This is Oberoi from Delhi who came here to study.
      
    
    '''
    # Check for spellings in English language
    spell = Speller(lang='en')
    Corrected_text = spell(text)
    return Corrected_text

# The code for lemmatization
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()
def lemmatization(text):
    """This function converts word to their root words 
       without explicitely cut down as done in stemming.
    
    arguments:
         input_text: "text" of type "String".
         
    return:
        value: Text having root words only, no tense form, no plural forms
        
    Example: 
    Input : text reduced 
    Output :  text reduce
    
   """
    # Converting words to their root forms
    lemma = [lemmatizer.lemmatize(w,'v') for w in w_tokenizer.tokenize(text)]
    return lemma


# The code for removing stopwords
stoplist = stopwords.words('english') 
stoplist = set(stoplist)
def removing_stopwords(text):
    """This function will remove stopwords which doesn't add much meaning to a sentence 
       & they can be remove safely without comprimising meaning of the sentence.
    
    arguments:
         input_text: "text" of type "String".
         
    return:
        value: Text after omitted all stopwords.
        
    Example: 
    Input : This is Kajal from delhi who came here to study.
    Output : ["'This", 'Kajal', 'delhi', 'came', 'study', '.', "'"] 
    
   """
    # repr() function actually gives the precise information about the string
    text = repr(text)
    # Text without stopwords
    No_StopWords = [word for word in word_tokenize(text) if word.lower() not in stoplist ]
    # Convert list of tokens_without_stopwords to String type.
    words_string = ' '.join(No_StopWords)    
    return words_string

data1=data.copy()
#Remove al NAN values from responses
data1.dropna(subset=['responses'],inplace=True)
data1.reset_index(drop=True, inplace=True)

# Pre-processing for Content
List_Content = data1['responses'].to_list()
Final_Response = []
Complete_Content = []
tokens_response=[]
Complete_tokens=[]

#
i=0
print(List_Content)
for article in List_Content:
    if not (article!=article):      
      #remove white spaces
      Processed_Content=remove_newlines_tabs(article)
      Processed_Content=remove_whitespace(Processed_Content) 
      Processed_Content=strip_html_tags(Processed_Content) 
      Processed_Content=remove_links(Processed_Content) 
      Processed_Content=strip_accents(Processed_Content) 
      Processed_Content=lower_casing_text(Processed_Content) 
      Processed_Content=reducing_incorrect_character_repeatation(Processed_Content) 
      Processed_Content=expand_contractions(Processed_Content) 
      Processed_Content=removing_special_characters(Processed_Content) 

      #stoplist = stopwords.words('english') 
      #stoplist = set(stoplist)
    
      #Processed_Content = removing_stopwords(Processed_Content)       
      spell = Speller(lang='en')    
      Processed_Content = spelling_correction(Processed_Content)        
      
      w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
      lemmatizer = nltk.stem.WordNetLemmatizer()
    
      tokens_response.append(lemmatization(Processed_Content))

      Final_Response.append(Processed_Content)
      i=i+1
    #avoid Nan Values
    #else:
    #  data.drop
    #  Final_Response.append(article)
    #  tokens_response.append(article) 
print(Final_Response)


Complete_Content.extend(Final_Response)
Complete_tokens.extend(tokens_response)
data1['Processed_Responses'] = Complete_Content
data1['token_Responses'] = Complete_tokens
data1
# did not use stop words , I did lowercase, review the others
# Out:
# ['An erroneous set culture that promotes a race-based, elitist "status" for engineers who are not part of a set "norm".', 'Objective not found in the curriculum', 'Informal and hidden messages, concepts, ideas, and beliefs transmitted in non verbal or semi verbal way that "shape" the education and beliefs of students and community', 'Information to be learned but that is most time disregarded', 'things that we learn in school that are not specified that we are gonna learn.', 'Is the uninteded lessons that students may learn in school.', "The stuff teachers mention on class that isn't on the curriculum and wonâ€™t be evaluated on the test but is still important", 'unwritten lessons or values learned at school', 'stigma about something', "Assumptions bades on people's perceptions.", 'Hidden curriculum includes the history (people/culture), social impact, or ideas that contribute to the field of engineering, but are not taught in a traditional classroom. ', 'Things to complement the tea
# ...

# %%
#Vader Valance Calculation
#This code will provide colums Vader_result,	compound and	compound_val
#Vader_result: will provide negative, positve , neutral and compound values for vader
#compound	is a separate  column  for the compund values from vader
#compound_val is a label either positive or negative depending of the compound value

Final_Response = []
Complete_Content = []
Compound_Value=[]
Complete_Vader=[]
c_score=[]

for article in data1['Processed_Responses']:
    if not (article!=article):   
      Final_Response.append(sid.polarity_scores(article))
      Compound_Value.append(sid.polarity_scores(article)['compound'])
    else:
      Final_Response.append(article)     
      Compound_Value.append(article)     
#create Vader colum  
Complete_Content.extend(Final_Response)
Complete_Vader.extend(Compound_Value)
data1['Vader_result'] = Complete_Content
data1['compound'] = Complete_Vader

#Get positive and Negative Compound Values
data1['compound_val']=data1['compound'].apply(lambda c: 'NaN' if c!=c else ( 'pos' if c>=0  else 'neg'))

# %%
data1
# Out:
#                                              responses  \
# 0    An erroneous set culture that promotes a race-...
# 1                Objective not found in the curriculum
# 2    Informal and hidden messages, concepts, ideas,...
# 3    Information to be learned but that is most tim...
# 4    things that we learn in school that are not sp...
# ..                                                 ...
# 913  The curriculum of actual self improvment to be...
# 914  I think hidden curriculum refers to the unwrit...
# 915  You donâ€™t know you have until you find your ...
# 916  things which we learn , without neccessarily b...
# 917                           muy bueno el curriculoun
#
#                                           roles                      field  \
# 0    Undergraduate student- 3rd year or greater     Mechanical Engineering
# 1                             Transfer Student      Mechanical Engineering
# 2                                Full professor       Computer Engineering
# ...

# %% [markdown]
# #### 4. Results
#
# > You can provide your Results here

# %%
#This code  will provide analisis for vader resuls depending on demographics

print(data1[['compound']].describe())

#data.hist(column='compound_val');
# Creating histogram

 
#data.hist(column='compound',by='gender');
print("Histogram by gender")
ax = data1.hist(column='compound', bins=25, grid=False, figsize=(26,16), color='#86bf91', zorder=2, rwidth=0.9 , by='gender')

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)


ax = data1.hist(column='compound', bins=25, grid=False, figsize=(26,16), color='#86bf91', zorder=2, rwidth=0.9 , by='First Generation')

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    #x.set_title("Histogram by First Generation Student")

    # Set x-axis label
    #x.set_xlabel("Session Duration (Seconds)", labelpad=20, weight='bold', size=12)

ax = data1.hist(column='compound', bins=25, grid=False, figsize=(26,16), color='#86bf91', zorder=2, rwidth=0.9 , by='Non Tradional')

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    #x.set_title("Histogram by First Generation Student")

    # Set x-axis label
    #x.set_xlabel("Session Duration (Seconds)", labelpad=20, weight='bold', size=12)
    

ax = data1.hist(column='compound', bins=25, grid=False, figsize=(26,16), color='#86bf91', zorder=2, rwidth=0.9 , by='roles')

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)



ax = data1.hist(column='compound', bins=25, grid=False, figsize=(26,20), color='#86bf91', zorder=2, rwidth=0.9 , by='field')

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)
# Out:
#          compound
# count  918.000000
# mean     0.100393
# std      0.280287
# min     -0.823800
# 25%      0.000000
# 50%      0.000000
# 75%      0.290300
# max      0.895700
# Histogram by gender

# %%
#Here I train a Naive bayes classifier using a positive or negative label from vader
#results
#https://iq.opengenus.org/naive-bayes-on-tf-idf-vectorized-matrix/
# Training Naive Classsifer


#Data_X = data1['token_Responses']   # '0' corresponds to Texts/Reviews
Data_X = data1['Processed_Responses']   # '0' corresponds to Texts/Reviews
Data_y = data1['compound_val']   # '1' corresponds to Label (1 - positive and 0 - negative)

X_train, X_test, y_train, y_test = train_test_split(Data_X, Data_y, test_size=0.20, random_state=42)

t = time()  # not compulsory

# loading CountVectorizer
tf_vectorizer = CountVectorizer() # or term frequency
X_train_tf = tf_vectorizer.fit_transform(X_train)
#X_train_tf = [tf_vectorizer.fit_transform(word) for word in X_train]


#Applying tf vectorizer (count vectorizer)
#Here, we use CountVectorizer (another term of TfVectorizer)
duration = time() - t
print("Time taken to extract features from training data : %f seconds" % (duration))
print("n_samples: %d, n_features: %d" % X_train_tf.shape)

#Transforming test data into tf-vectorized matrix
t = time()
X_test_tf = tf_vectorizer.transform(X_test)

duration = time() - t
print("Time taken to extract features from test data : %f seconds" % (duration))
print("n_samples: %d, n_features: %d" % X_test_tf.shape)

#Applying Naive Bayes
t = time()

naive_bayes_classifier = MultinomialNB()
naive_bayes_classifier.fit(X_train_tf, y_train)

training_time = time() - t
print("train time: %0.3fs" % training_time)

#Calculating accuracy and generating classification report from test data
# predict the new document from the testing dataset
t = time()
y_pred = naive_bayes_classifier.predict(X_test_tf)

test_time = time() - t
print("test time:  %0.3fs" % test_time)

# compute the performance measures
score1 = metrics.accuracy_score(y_test, y_pred)
print("\naccuracy:   %0.3f" % score1)

print(metrics.classification_report(y_test, y_pred,target_names=['pos', 'neg']))

print("\nconfusion matrix:")
print(metrics.confusion_matrix(y_test, y_pred))

print('------------------------------')

from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix

#-------Confusion Matrix and Metrics
print("y_train prediction",accuracy_score(y_test, y_pred))

fig, ax = plt.subplots(figsize=(15, 15))
plot_confusion_matrix(naive_bayes_classifier, X_test_tf, y_test,  cmap=plt.cm.Blues, ax=ax)
#plot_confusion_matrix(naive_bayes_classifier, X_test, y_pred,  cmap=plt.cm.Blues, ax=ax)
plt.show()
print(metrics.classification_report(y_test, y_pred))
# Out:
# Time taken to extract features from training data : 0.025612 seconds
# n_samples: 734, n_features: 1396
# Time taken to extract features from test data : 0.003638 seconds
# n_samples: 184, n_features: 1396
# train time: 0.009s
# test time:  0.002s
#
# accuracy:   0.897
#               precision    recall  f1-score   support
#
#          pos       0.50      0.05      0.10        19
#          neg       0.90      0.99      0.95       165
#
#     accuracy                           0.90       184
#    macro avg       0.70      0.52      0.52       184
# weighted avg       0.86      0.90      0.86       184
#
#
# confusion matrix:
# [[  1  18]
#  [  1 164]]
# ------------------------------
# y_train prediction 0.8967391304347826
# ...

# %%
# Out:
# Cloning into 'sklearn-theano'...
# remote: Enumerating objects: 888, done.
# remote: Total 888 (delta 0), reused 0 (delta 0), pack-reused 888
# Receiving objects: 100% (888/888), 2.76 MiB | 36.28 MiB/s, done.
# Resolving deltas: 100% (460/460), done.

# %%
#Here I was trying to test the pre-trained emotion classifier
#a lot of problems with dependencies occured so this part was not implemented
import os;
os.environ['KERAS_BACKEND'] = 'theano'

import pandas as pd
from emotion_predictor import EmotionPredictor
#from emotion_predictor import EmotionPredictor

model = EmotionPredictor(classification='ekman', setting='mc')

tweets = ["Watching the sopranos again from start to finish!",
    "Finding out i have to go to the  dentist tomorrow",
    "I want to go outside and chalk but I have no chalk",
    "I HATE PAPERS AH #AH #HATE",
    "My mom wasn't mad",
    "Do people have no Respect for themselves or you know others peoples homes"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-167f51b2bb88> in <module>
#       6 #from emotion_predictor import EmotionPredictor
#       7
# ----> 8 model = EmotionPredictor(classification='ekman', setting='mc')
#       9
#      10 tweets = ["Watching the sopranos again from start to finish!",
#
# /content/emotion_predictor.py in __init__(self, classification, setting, use_unison_model)
#      28         self.setting = setting
#      29         self.use_unison_model = use_unison_model
# ---> 30         self.model = self._get_model()
#      31         self.embeddings_model = self._get_embeddings_model()
#      32         self.char_to_ind = self._get_char_mapping()
#
# /content/emotion_predictor.py in _get_model(self)
#      40             self.setting,
#      41         )
# ---> 42         return load_model(self._loaded_model_filename)
#      43
# ...

# %% [markdown]
# #### 5. Conclusion and Discussion
#
# Previous work suggests that faculties have higher or more positive expectations regarding students' performance in an authentic exam environment [4]. Faculties have a different contextual setup than students and for that same reason, the hypothesis is Faculties Will have more positive sentiments and emotions expressed to Hidden curriculum awareness than engineering students.
#
#
# When we observe the plots distributions for Vader results the data suggest an inclination to neutral responses from all respondents including professors and students. Students in their first and second years seem to have more positive responses about hidden curriculum than junior/senior or graduate students.
#
# Only adjunct professors had negative responses regarding the hidden curriculum when compare with their fellows who overall had neutral responses as can see in the plots above. When compared with the field of study or specialization the Vader valence varied among the different fields.
#
# The Vader sentiment analysis results were fed to a naive Bayes classifier. The classifier provided a 89.7%  accuracy. Although this is a good result The Data was skewed towards positiveness.  A pre-trained RNN could not be performed in this project as proposed due to issues in dependencies with keras and TensorFlow both locally and in google Colab.
#
# For future work, other algorithms should be investigated and compared. also compare differences when using other vectorizers. Also,  we want to expand the exploration of topic modeling and combine other hybrid models for this data.
#
# The use of NLP can enhance qualitative analyses and provide a faster and better understanding of data analyses when used appropriately. In the context of the hidden curriculum, there is not much literature related to it , especially in engineering. There is a lot of room and potential for more work to be explored.

# %% [markdown]
# ###6.	REFERENCES
#
# [1]	Villanueva, I., Diestafano, M.,Youmans, K.,  Hunt, A. (2022). Development and Assessment of a Vignette Survey Instru-ment to Identify Responses due to Hidden Curriculum among Engineering Students and Faculty.
#
# [2]	Ridhwan, K., Hargreaves, C., (2021). Leveraging Twitter Data to Understand Public Sentiment for the COVID‐19 Outbreak in Singapore. International Journal of Information Manage-ment Data Insights. 1. 100021. 10.1016/j.jjimei.2021.100021.
#
# [3]	N. Colnerič and J. Demšar, "Emotion Recognition on Twitter: Comparative Study and Training a Unison Model," in IEEE Transactions on Affective Computing, vol. 11, no. 3, pp. 433-446, 1 July-Sept. 2020, doi: 10.1109/TAFFC.2018.2807817.
#
# [4]	Villanueva, I., Zorrilla, E.M., Husman, J., Graham, M. (2021). Human-Technology Frontier: Measuring Student Per-formance-Related Responses to Authentic Engineering Educa-tion Activities via Physiological Sensing.
#
# [5]	I. Villanueva, R. A. Revelo and J. A. Mejia, "Professional development of Latinx engineers on hidden curriculum: An exploratory study," 2019 IEEE Frontiers in Education Confer-ence (FIE), 2019, pp. 1-5, doi: 10.1109/FIE43999.2019.9028632.
#
# [6]	I. Villanueva, M. Di Stefano, L. Gelles, K. Youmans, and A. Hunt, “Development and validation of a survey to explore hidden curriculum in engineering,” IJEE, in preparation
#
# [7]	I. Villanueva, L. Gelles, M. Di Stefano, B. Smith….G. Ryan, “What does hidden curriculum look like and how can it be ex-plored” Proc. ASEE Annual Conference & Expo, 2018, pp. 1-16
#
# [8]	] I.Villanueva, T. Carothers, M. Di Stefano, and M.T.H.Khan, “ ‘There is Never a Break’: The hidden curriculum of profes-sionalization for engineering faculty,” Educ. Sci., 2018, 8, 57, pp.1-21
#
# [9]	Villanueva, I., Stefano, M.D., Gelles, L.A., & Youmans, K. (2018). Hidden Curriculum Awareness: A Comparison of Engineering Faculty, Graduate Students, and Undergraduates.
